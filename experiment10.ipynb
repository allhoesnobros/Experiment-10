# %% [markdown]
# <a href="https://colab.research.google.com/github/allhoesnobros/Experiment-10/blob/main/experiment10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Experiment 10
# Aayush Vishwakarma
# 25070123125

# %%
import pandas as pd
s=pd.Series([10,20,30,40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
data={
    "Name":["A","B","C"],
    "Marks":[10,20,30]
}
df=pd.DataFrame(data)
print(df)
# Out:
#   Name  Marks
# 0    A     10
# 1    B     20
# 2    C     30

# %%
df.shape
# Out:
# (3, 2)

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 6

# %%
df.columns
# Out:
# Index(['Name', 'Marks'], dtype='object')

# %%
#Check datatype of each column
df.dtypes
# Out:
# Name     object
# Marks     int64
# dtype: object

# %%
#Access individual column
df["Name"]
# Out:
# 0    A
# 1    B
# 2    C
# Name: Name, dtype: object

# %%
df["Marks"]
# Out:
# 0    10
# 1    20
# 2    30
# Name: Marks, dtype: int64

# %%
#Access to the first row
df.loc[0,"Name"]
# Out:
# 'A'

# %%
df.iloc[1]
# Out:
# Name      B
# Marks    20
# Name: 1, dtype: object

# %%
#Add a new column
df["Grade"]=["First class", "Distinction", "Second Class"]

# %%
print(df)
# Out:
#   Name Marks         Grade
# 0    A    81   First class
# 1    B    91   Distinction
# 2    C    30  Second Class

# %%
df.loc[0, "Marks"]= 81

# %%
print(df)
# Out:
#   Name Marks         Grade
# 0    A    81   First class
# 1    B    91   Distinction
# 2    C    30  Second Class

# %%
df.iloc[1,1]= 91
print(df)
# Out:
#   Name Marks         Grade
# 0    A    81   First class
# 1    B    91   Distinction
# 2    C    30  Second Class

# %%
#inplace will overwrite a data

# %%
#df.drop("Grade",axis=1,inplace=True)
df1=df.drop("Grade", axis=1)
print(df1)
print(df)
# Out:
#   Name Marks
# 0    A    81
# 1    B    91
# 2    C    30
#   Name Marks         Grade
# 0    A    81   First class
# 1    B    91   Distinction
# 2    C    30  Second Class

# %%
#Perform basic statistical analysis
mean1=df["Marks"].mean()
mean1
# Out:
# np.float64(67.33333333333333)

# %%
min1=df["Marks"].min()
min1
# Out:
# 30

# %%
print(df[df["Marks"]>80])
# Out:
#   Name Marks        Grade
# 0    A    81  First class
# 1    B    91  Distinction

# %%
max1=df["Marks"].max()
print(max1)
# Out:
# 91
